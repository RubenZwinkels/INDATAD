# %% [markdown]
# # beschrijvende analyse op de statistishe data (van kaggle)

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from collections import Counter

df = pd.read_csv("../popularity/Kaggle_TED_video_metadata_balanced.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          600 non-null    object
#  1   tags           590 non-null    object
#  2   views          600 non-null    int64
#  3   likes          600 non-null    int64
#  4   dislikes       600 non-null    int64
#  5   comment_count  600 non-null    int64
#  6   published_at   600 non-null    object
#  7   duration       600 non-null    object
#  8   category_id    600 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 42.3+ KB

# %%
fig = px.histogram(df, x='views', nbins=20, title='verdeling van views')
fig.show()
# Out:
# <div>                            <div id="b4f897f0-169c-455e-b880-ae1b2480e9e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4f897f0-169c-455e-b880-ae1b2480e9e7")) {                    Plotly.newPlot(                        "b4f897f0-169c-455e-b880-ae1b2480e9e7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"views=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[77455,800326,87635,190840,98523,168959,1711699,3208645,105009,6089724,65631,345655,638041,354,5043338,51036,81091,1475636,155126,86822,79566,1804509,6551133,279474,15127261,85109,30979
# ...

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

fig = px.scatter(df, x='published_at', y='views', title='Views over Tijd')
fig.show()
# Out:
# <div>                            <div id="b6577e9f-4a1e-4a79-aa82-4c7dc9b4676d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6577e9f-4a1e-4a79-aa82-4c7dc9b4676d")) {                    Plotly.newPlot(                        "b6577e9f-4a1e-4a79-aa82-4c7dc9b4676d",                        [{"hovertemplate":"published_at=%{x}\u003cbr\u003eviews=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2017-03-24T15:32:48+00:00","2017-08-01T15:29:04+00:00","2017-05-30T18:17:56+00:00","2017-04-12T15:17:51+00:00","2017-07-25T15:06:25+00:00","2017-07-24T20:36:58+00:00","2013-06-19T16:14:01+00:00","2017-08-14T15:17:59+00:00","2017-07-
# ...

# %%
# Scatter plot voor views en likes
fig = px.scatter(df, x='views', y='likes', title='Relatie tussen Views en Likes')
fig.show()
# Out:
# <div>                            <div id="495e308f-17c1-4814-90c6-e2abca7fe5f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("495e308f-17c1-4814-90c6-e2abca7fe5f6")) {                    Plotly.newPlot(                        "495e308f-17c1-4814-90c6-e2abca7fe5f6",                        [{"hovertemplate":"views=%{x}\u003cbr\u003elikes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[77455,800326,87635,190840,98523,168959,1711699,3208645,105009,6089724,65631,345655,638041,354,5043338,51036,81091,1475636,155126,86822,79566,1804509,6551133,279474,15127261,85109,309795,15380,643820,134567,131709,85705,123309,187444,762236,
# ...

# %%
fig = px.violin(df, x='category_id', y='likes', title='Verdeling van Likes per Categorie', box=True, points="all")
fig.show()
# Out:
# <div>                            <div id="e69fd944-e266-4cf0-9785-b0357821e132" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e69fd944-e266-4cf0-9785-b0357821e132")) {                    Plotly.newPlot(                        "e69fd944-e266-4cf0-9785-b0357821e132",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"category_id=%{x}\u003cbr\u003elikes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","points":"all","scalegroup":"True","showlegend":false,"x":[29,22,22,22,29,28,25,28,25,22,28,22,22,28,28,29,22,29,29,28,28,28,23,28,28,28,28,27,22,28,27,28,25,28,28,28,27,28,29,10,27,28,22,22,29,2,28,22,10,28,22,28,25,24,28,22,29,
# ...

# %%
# Correlatie matrix berekenen
corr_matrix = df[['views', 'likes', 'comment_count']].corr()

fig = go.Figure(data=go.Heatmap(
        z=corr_matrix.values,
        x=['views', 'likes', 'comment_count'],
        y=['views', 'likes', 'comment_count'],
        colorscale='Viridis'))

fig.update_layout(title='Correlatie Heatmap van Views, Likes, Dislikes en Commentaren')
fig.show()
# Out:
# <div>                            <div id="e538ac2c-6dbc-4555-b5b6-f19da85012a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e538ac2c-6dbc-4555-b5b6-f19da85012a0")) {                    Plotly.newPlot(                        "e538ac2c-6dbc-4555-b5b6-f19da85012a0",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":["views","likes","comment_count"],"y":["views","likes","comment_count"],"z":[[1.0,0.9268292906258009,0.871476208959593],[0.9268292906258009,1.0,0.9053112452636315],[0.
# ...

# %% [markdown]
# ##### In deze heatmap is te concluderen dat er erg hoge correlatie is tussen alle factoren.

# %%
# Duur omzetten naar minuten (veronderstel dat de duur in de vorm van "HH:MM:SS" is)
df['duration_seconds'] = pd.to_timedelta(df['duration']).dt.total_seconds() / 60  # Omzetten naar minuten

# Scatterplot voor Duur vs. Views
fig = px.scatter(df, x='duration_seconds', y='views', title='Duur van Video vs. Aantal Views', labels={'duration_seconds': 'Duur (minuten)'})
fig.show()
# Out:
# <div>                            <div id="7dc29028-3850-43fa-bc55-ffb700a9eda7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dc29028-3850-43fa-bc55-ffb700a9eda7")) {                    Plotly.newPlot(                        "7dc29028-3850-43fa-bc55-ffb700a9eda7",                        [{"hovertemplate":"Duur (minuten)=%{x}\u003cbr\u003eviews=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15.316666666666666,9.5,10.816666666666666,11.933333333333334,14.233333333333333,13.983333333333333,13.866666666666667,14.566666666666666,14.516666666666667,15.533333333333333,5.183333333333334,14.15,10.033333333333333,3.28333333333
# ...
